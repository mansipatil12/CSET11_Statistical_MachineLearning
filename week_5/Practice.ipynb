# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

# %%
mean_x=np.mean(x)
mean_y=np.mean(y)
n=len(x)
print("Mean of x is:",mean_x)
print("Mean of y is:",mean_y)
# Out:
# Mean of x is: 3.0
# Mean of y is: 6.0

# %%
numerator=np.sum((x - mean_x) * (y - mean_y))
denominator=np.sum((x - mean_x) ** 2)
m = numerator / denominator
print("Slope(m):", m)
# Out:
# Slope(m): 2.0

# %%
c = mean_y-m*mean_x
print("Intercept(c):", c)
# Out:
# Intercept(c): 0.0

# %%
regression_line_x = np.linspace(np.min(x), np.max(x), 100)
regression_line_y = m * regression_line_x + c
plt.scatter(x, y, label='Data Points')
plt.plot(regression_line_x, regression_line_y, color='red', label='Regression Line')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()
